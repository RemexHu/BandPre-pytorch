# %%
import numpy as np
import matplotlib.pylab as plt
import padasip as pa 

# these two function supplement your online measurment
def measure_x():
    # it produces input vector of size 3
    x = np.random.random(3)
    print(x.shape)
    return x
    
def measure_d(x):
    # meausure system output
    d = 2*x[0] + 1*x[1] - 1.5*x[2]
    #print(d.shape)
    return d
    
N = 10
log_d = np.zeros(N)
log_y = np.zeros(N)
filt = pa.filters.FilterRLS(3, mu=0.5)
for k in range(N):
    # measure input
    x = measure_x()
    print
    # predict new value
    y = filt.predict(x)
    # do the important stuff with prediction output
    pass    
    # measure output
    d = measure_d(x)
    # update filter
    filt.adapt(d, x)
    # log values
    log_d[k] = d
    log_y[k] = y
    
### show results
plt.figure(figsize=(15,9))
plt.subplot(211);plt.title("Adaptation");plt.xlabel("samples - k")
plt.plot(log_d,"b", label="d - target")
plt.plot(log_y,"g", label="y - output");plt.legend()
plt.subplot(212);plt.title("Filter error");plt.xlabel("samples - k")
plt.plot(10*np.log10((log_d-log_y)**2),"r", label="e - error [dB]")
plt.legend(); plt.tight_layout(); plt.show()
# Out:
# (3,)
# (3,)
# (3,)
# (3,)
# (3,)
# (3,)
# (3,)
# (3,)
# (3,)
# (3,)

# %%
import pandas
from sklearn.metrics import mean_squared_error
import math
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-df0d3fe5989b> in <module>()
#       1 import pandas
# ----> 2 from sklearn.metrics import mean_squared_error
#       3 import math
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
file = pandas.read_csv('train.oslo-vestby-report.2011-02-11_1618CET.log', names = ["band"], sep = '\t')
dataset = file["band"][:]
dataset = np.asarray(dataset).astype(float)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-5e1a3d0964d5> in <module>()
# ----> 1 file = pandas.read_csv('train.oslo-vestby-report.2011-02-11_1618CET.log', names = ["band"], sep = '\t')
#       2 dataset = file["band"][:]
#       3 dataset = np.asarray(dataset).astype(float)
#
# ...

# %%
data_x, data_y = [], []
for i in range(20, len(dataset)):
    batch_x = dataset[i - 20: i]
    batch_y = dataset[i]
    data_x.append(batch_x)
    data_y.append(np.array(batch_y))

#data_x, data_y = np.asarray(data_x), np.asarray(data_y)

# %%
print(data_x[0].shape)
print(data_y[0].shape)
# Out:
# (20,)
# ()

# %%
filt = pa.filters.FilterRLS(20, mu=0.2)
pred = np.zeros(dataset.shape[0])

for cur in range(len(data_x)):
    prediction = filt.predict(data_x[cur])
    filt.adapt(data_y[cur], data_x[cur])
    pred[cur + 20] = prediction



plt.figure(figsize=(25,9))
plt.plot(pred[:500])
plt.plot(dataset[:500])
plt.show()


MSEloss = math.sqrt(mean_squared_error(pred[20:], dataset[20:]))

print(MSEloss)
# Out:
# 0.6589921028811191

# %%
filt = pa.filters.FilterRLS(20, mu=0.5)
pred = np.zeros(dataset.shape[0])

for cur in range(len(data_x)):
    prediction = filt.predict(data_x[cur])
    filt.adapt(data_y[cur], data_x[cur])
    pred[cur + 20] = prediction
    
plt.figure(figsize=(25,9))
plt.plot(pred[:500])
plt.plot(dataset[:500])
plt.show()

MSEloss = math.sqrt(mean_squared_error(pred[20:], dataset[20:]))

print(MSEloss)
# Out:
# 0.6323937180341321

# %%
filt = pa.filters.FilterRLS(20, mu=0.8)
pred = np.zeros(dataset.shape[0])

for cur in range(len(data_x)):
    prediction = filt.predict(data_x[cur])
    filt.adapt(data_y[cur], data_x[cur])
    pred[cur + 20] = prediction
    
plt.figure(figsize=(25,9))
plt.plot(pred[:500])
plt.plot(dataset[:500])
plt.show()

MSEloss = math.sqrt(mean_squared_error(pred[20:], dataset[20:]))

print(MSEloss)
# Out:
# 0.8833674152475361

# %%
filt = pa.filters.FilterRLS(20, mu=0.90)
pred = np.zeros(dataset.shape[0])

for cur in range(len(data_x)):
    prediction = filt.predict(data_x[cur])
    filt.adapt(data_y[cur], data_x[cur])
    pred[cur + 20] = prediction
    
plt.figure(figsize=(25,9))
plt.plot(pred[:500])
plt.plot(dataset[:500])
plt.show()

MSEloss = math.sqrt(mean_squared_error(pred[20:], dataset[20:]))

print(MSEloss)
# Out:
# 0.9824790179635273

# %%
num = np.linspace(0.01, 0.99, 100)
mini = 999
best = 0

for mu in num:

    filt = pa.filters.FilterRLS(20, mu=mu)
    pred = np.zeros(dataset.shape[0])

    for cur in range(len(data_x)):
        prediction = filt.predict(data_x[cur])
        filt.adapt(data_y[cur], data_x[cur])
        pred[cur + 20] = prediction

    MSEloss = math.sqrt(mean_squared_error(pred[20:], dataset[20:]))
    if mini > MSEloss: 
        mini = MSEloss
        print(mu, mini)
        best = mu
# Out:
# 0.01 0.7160659137265252
# 0.0198989898989899 0.70519894688797
# 0.029797979797979796 0.6828116209145089
# 0.08919191919191918 0.6709985882604205
# 0.10898989898989898 0.6700815124572658
# 0.11888888888888888 0.667294267187715
# 0.12878787878787878 0.6603292612376895
# 0.207979797979798 0.6441361368606007
# 0.21787878787878787 0.6412985374190766
# 0.30696969696969695 0.639903232732332
# 0.32676767676767676 0.6347577497738094
# 0.36636363636363634 0.6232703504860719
# 0.39606060606060606 0.6125175552537976
# 0.43565656565656563 0.6094869424152793
# 0.46535353535353535 0.6048395820971966
# 0.6336363636363637 0.5919387307952609

# %%
filt = pa.filters.FilterRLS(20, mu=0.60)
pred = np.zeros(dataset.shape[0])

for cur in range(len(data_x)):
    prediction = filt.predict(data_x[cur])
    filt.adapt(data_y[cur], data_x[cur])
    pred[cur + 20] = prediction

diff = dataset - pred
plt.figure(figsize=(25,9))
plt.plot(diff[1000:])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9b1e6fbdbb1b> in <module>()
#       1 filt = pa.filters.FilterRLS(20, mu=0.60)
# ----> 2 pred = np.zeros(dataset.shape[0])
#       3
#       4 for cur in range(len(data_x)):
#       5     prediction = filt.predict(data_x[cur])
#
# NameError: name 'dataset' is not defined

# %%
plt.figure(figsize=(25,9))
plt.plot(pred[1400:])
plt.plot(dataset[1400:])
plt.show()
